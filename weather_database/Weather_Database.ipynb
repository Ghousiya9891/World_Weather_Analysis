# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.00,high=90,size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# for x in coordinates:
  #  print(x[0],x[1])

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities=[]
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    # print(city)
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        # YOUR CODE HERE
        cities.append(city)

# Print the city count to confirm sufficient count
# YOUR CODE HERE
len(cities)
# Out:
# 604

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lng = city_weather["coord"]["lon"]
        city_lat=city_weather["coord"]["lat"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_description=city_weather["weather"][0]["description"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')   
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Date": city_date,
                         "Current Description":city_description})
        # YOUR CODE HERE
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kizukuri
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | sorong
# Processing Record 4 of Set 1 | pompeu
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | dharchula
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | matara
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | zlitan
# Processing Record 11 of Set 1 | sitka
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | ola
# Processing Record 14 of Set 1 | saskylakh
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | ayan
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | tabas
# Processing Record 21 of Set 1 | katsuura
# Processing Record 22 of Set 1 | tura
# Processing Record 23 of Set 1 | zavetnoye
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 1 | araouane
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | norman wells
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | edd
# Processing Record 31 of Set 1 | requena
# Processing Record 32 of Set 1 | pangody
# Processing Record 33 of Set 1 | amapa
# Processing Record 34 of Set 1 | sungairaya
# Processing Record 35 of Set 1 | talnakh
# Processing Record 36 of Set 1 | lagoa
# Processing Record 37 of Set 1 | tsiroanomandidy
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | marquette
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | svetlyy
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 1 | borogontsy
# Processing Record 45 of Set 1 | tuktoyaktuk
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | aranos
# Processing Record 48 of Set 1 | neiafu
# Processing Record 49 of Set 1 | esperance
# Processing Record 50 of Set 1 | bojonegoro
# Processing Record 1 of Set 2 | salalah
# Processing Record 2 of Set 2 | lompoc
# Processing Record 3 of Set 2 | klaksvik
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | marathon
# Processing Record 6 of Set 2 | cidreira
# Processing Record 7 of Set 2 | rudraprayag
# Processing Record 8 of Set 2 | korla
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | tarana
# Processing Record 11 of Set 2 | colares
# Processing Record 12 of Set 2 | kango
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | ugoofaaru
# Processing Record 15 of Set 2 | keskin
# Processing Record 16 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 2 | prabumulih
# Processing Record 18 of Set 2 | cabedelo
# Processing Record 19 of Set 2 | lima
# Processing Record 20 of Set 2 | palmer
# Processing Record 21 of Set 2 | mar del plata
# Processing Record 22 of Set 2 | cabo san lucas
# Processing Record 23 of Set 2 | great falls
# Processing Record 24 of Set 2 | tasiilaq
# Processing Record 25 of Set 2 | garmsar
# Processing Record 26 of Set 2 | half moon bay
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | vanimo
# Processing Record 30 of Set 2 | geraldton
# Processing Record 31 of Set 2 | avarua
# Processing Record 32 of Set 2 | pangai
# Processing Record 33 of Set 2 | port lincoln
# Processing Record 34 of Set 2 | cherskiy
# Processing Record 35 of Set 2 | roebourne
# Processing Record 36 of Set 2 | vila velha
# Processing Record 37 of Set 2 | taoudenni
# Processing Record 38 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 2 | hermanus
# Processing Record 40 of Set 2 | port hardy
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | kapaa
# Processing Record 43 of Set 2 | codrington
# Processing Record 44 of Set 2 | ponta do sol
# Processing Record 45 of Set 2 | hue
# Processing Record 46 of Set 2 | busselton
# Processing Record 47 of Set 2 | mehamn
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | bethel
# Processing Record 50 of Set 2 | alyangula
# Processing Record 1 of Set 3 | sechura
# Processing Record 2 of Set 3 | victoria
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 3 | avera
# Processing Record 6 of Set 3 | yining
# Processing Record 7 of Set 3 | tual
# Processing Record 8 of Set 3 | pisco
# Processing Record 9 of Set 3 | dikson
# Processing Record 10 of Set 3 | bayan
# Processing Record 11 of Set 3 | saint-philippe
# Processing Record 12 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 3 | kaoma
# Processing Record 14 of Set 3 | kodiak
# Processing Record 15 of Set 3 | ubauro
# Processing Record 16 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 3 | vizinga
# Processing Record 18 of Set 3 | henties bay
# Processing Record 19 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 20 of Set 3 | vihari
# Processing Record 21 of Set 3 | biltine
# Processing Record 22 of Set 3 | pevek
# Processing Record 23 of Set 3 | saldanha
# Processing Record 24 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 3 | lac du bonnet
# Processing Record 26 of Set 3 | bredasdorp
# Processing Record 27 of Set 3 | cape town
# Processing Record 28 of Set 3 | chuy
# Processing Record 29 of Set 3 | arman
# Processing Record 30 of Set 3 | floro
# Processing Record 31 of Set 3 | saint george
# Processing Record 32 of Set 3 | tamandare
# Processing Record 33 of Set 3 | gaoual
# Processing Record 34 of Set 3 | bellevue
# Processing Record 35 of Set 3 | pocone
# Processing Record 36 of Set 3 | ancud
# Processing Record 37 of Set 3 | neuquen
# Processing Record 38 of Set 3 | cayenne
# Processing Record 39 of Set 3 | gushikawa
# Processing Record 40 of Set 3 | pocatello
# Processing Record 41 of Set 3 | berlevag
# Processing Record 42 of Set 3 | challans
# Processing Record 43 of Set 3 | portland
# Processing Record 44 of Set 3 | challapata
# Processing Record 45 of Set 3 | goderich
# Processing Record 46 of Set 3 | walvis bay
# Processing Record 47 of Set 3 | alice springs
# Processing Record 48 of Set 3 | we
# City not found. Skipping...
# Processing Record 49 of Set 3 | andenes
# Processing Record 50 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 4 | iracoubo
# Processing Record 2 of Set 4 | hornepayne
# Processing Record 3 of Set 4 | marshfield
# Processing Record 4 of Set 4 | williams lake
# Processing Record 5 of Set 4 | batagay-alyta
# Processing Record 6 of Set 4 | hasaki
# Processing Record 7 of Set 4 | rio grande
# Processing Record 8 of Set 4 | umm kaddadah
# Processing Record 9 of Set 4 | lebu
# Processing Record 10 of Set 4 | cairns
# Processing Record 11 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 4 | khatanga
# Processing Record 13 of Set 4 | seydisehir
# Processing Record 14 of Set 4 | sao filipe
# Processing Record 15 of Set 4 | aguie
# Processing Record 16 of Set 4 | huarmey
# Processing Record 17 of Set 4 | tungkang
# City not found. Skipping...
# Processing Record 18 of Set 4 | zhigansk
# Processing Record 19 of Set 4 | beloha
# Processing Record 20 of Set 4 | georgetown
# Processing Record 21 of Set 4 | kirakira
# Processing Record 22 of Set 4 | sakakah
# Processing Record 23 of Set 4 | faanui
# Processing Record 24 of Set 4 | barrow
# Processing Record 25 of Set 4 | tiksi
# Processing Record 26 of Set 4 | asau
# Processing Record 27 of Set 4 | moose factory
# Processing Record 28 of Set 4 | gombong
# Processing Record 29 of Set 4 | aleksandrov gay
# Processing Record 30 of Set 4 | torbay
# Processing Record 31 of Set 4 | mitu
# Processing Record 32 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 4 | west odessa
# Processing Record 34 of Set 4 | mariental
# Processing Record 35 of Set 4 | santa cruz
# Processing Record 36 of Set 4 | san cristobal
# Processing Record 37 of Set 4 | stornoway
# Processing Record 38 of Set 4 | champerico
# Processing Record 39 of Set 4 | hobart
# Processing Record 40 of Set 4 | rawson
# Processing Record 41 of Set 4 | los llanos de aridane
# Processing Record 42 of Set 4 | bambous virieux
# Processing Record 43 of Set 4 | kizema
# Processing Record 44 of Set 4 | santa vitoria do palmar
# Processing Record 45 of Set 4 | luanda
# Processing Record 46 of Set 4 | talawdi
# City not found. Skipping...
# Processing Record 47 of Set 4 | matamoros
# Processing Record 48 of Set 4 | shimoda
# Processing Record 49 of Set 4 | hamilton
# Processing Record 50 of Set 4 | maragogi
# Processing Record 1 of Set 5 | oranjemund
# Processing Record 2 of Set 5 | chakia
# Processing Record 3 of Set 5 | fokino
# Processing Record 4 of Set 5 | broken hill
# Processing Record 5 of Set 5 | antofagasta
# Processing Record 6 of Set 5 | chioggia
# Processing Record 7 of Set 5 | vilyuysk
# Processing Record 8 of Set 5 | hammerfest
# Processing Record 9 of Set 5 | northam
# Processing Record 10 of Set 5 | inta
# Processing Record 11 of Set 5 | narsaq
# Processing Record 12 of Set 5 | guarapari
# Processing Record 13 of Set 5 | lazaro cardenas
# Processing Record 14 of Set 5 | cockburn town
# Processing Record 15 of Set 5 | karatuzskoye
# Processing Record 16 of Set 5 | ambilobe
# Processing Record 17 of Set 5 | backo petrovo selo
# Processing Record 18 of Set 5 | tongchuan
# Processing Record 19 of Set 5 | upernavik
# Processing Record 20 of Set 5 | kaitangata
# Processing Record 21 of Set 5 | bichura
# Processing Record 22 of Set 5 | sigerfjord
# City not found. Skipping...
# Processing Record 23 of Set 5 | mandalgovi
# Processing Record 24 of Set 5 | angoche
# Processing Record 25 of Set 5 | burnie
# Processing Record 26 of Set 5 | kuito
# Processing Record 27 of Set 5 | singaraja
# Processing Record 28 of Set 5 | huangzhai
# Processing Record 29 of Set 5 | necochea
# Processing Record 30 of Set 5 | sangar
# Processing Record 31 of Set 5 | pinega
# Processing Record 32 of Set 5 | flinders
# Processing Record 33 of Set 5 | envira
# Processing Record 34 of Set 5 | izhma
# Processing Record 35 of Set 5 | arraial do cabo
# Processing Record 36 of Set 5 | saint-dizier
# Processing Record 37 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 5 | mareeba
# Processing Record 39 of Set 5 | menongue
# Processing Record 40 of Set 5 | opuwo
# Processing Record 41 of Set 5 | clyde river
# Processing Record 42 of Set 5 | hokitika
# Processing Record 43 of Set 5 | bar harbor
# Processing Record 44 of Set 5 | kosa
# Processing Record 45 of Set 5 | mahebourg
# Processing Record 46 of Set 5 | taltal
# Processing Record 47 of Set 5 | aklavik
# Processing Record 48 of Set 5 | jumla
# Processing Record 49 of Set 5 | punta alta
# Processing Record 50 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 6 | wanning
# Processing Record 2 of Set 6 | bathsheba
# Processing Record 3 of Set 6 | pochutla
# Processing Record 4 of Set 6 | santa elena
# Processing Record 5 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 6 | kavaratti
# Processing Record 7 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 6 | troitsko-pechorsk
# Processing Record 10 of Set 6 | markivka
# Processing Record 11 of Set 6 | nyirlugos
# Processing Record 12 of Set 6 | ribeira grande
# Processing Record 13 of Set 6 | uvalde
# Processing Record 14 of Set 6 | mogadishu
# Processing Record 15 of Set 6 | beyneu
# Processing Record 16 of Set 6 | pombas
# Processing Record 17 of Set 6 | kuremaa
# Processing Record 18 of Set 6 | mayskiy
# Processing Record 19 of Set 6 | zhaodong
# Processing Record 20 of Set 6 | dodge city
# Processing Record 21 of Set 6 | touho
# Processing Record 22 of Set 6 | ilulissat
# Processing Record 23 of Set 6 | aksehir
# Processing Record 24 of Set 6 | iqaluit
# Processing Record 25 of Set 6 | port hedland
# Processing Record 26 of Set 6 | grindavik
# Processing Record 27 of Set 6 | palu
# Processing Record 28 of Set 6 | dosso
# Processing Record 29 of Set 6 | te anau
# Processing Record 30 of Set 6 | alta floresta
# Processing Record 31 of Set 6 | monticello
# Processing Record 32 of Set 6 | sitagroi
# Processing Record 33 of Set 6 | la ronge
# Processing Record 34 of Set 6 | mallaig
# Processing Record 35 of Set 6 | brigantine
# Processing Record 36 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 6 | beysehir
# Processing Record 38 of Set 6 | nuevo ideal
# Processing Record 39 of Set 6 | mersing
# Processing Record 40 of Set 6 | kholtoson
# Processing Record 41 of Set 6 | bafra
# Processing Record 42 of Set 6 | noumea
# Processing Record 43 of Set 6 | guerrero negro
# Processing Record 44 of Set 6 | adrar
# Processing Record 45 of Set 6 | saquarema
# Processing Record 46 of Set 6 | qasigiannguit
# Processing Record 47 of Set 6 | rabo de peixe
# Processing Record 48 of Set 6 | morondava
# Processing Record 49 of Set 6 | vardo
# Processing Record 50 of Set 6 | sisimiut
# Processing Record 1 of Set 7 | provideniya
# Processing Record 2 of Set 7 | leningradskiy
# Processing Record 3 of Set 7 | yuncheng
# Processing Record 4 of Set 7 | hualmay
# Processing Record 5 of Set 7 | abu samrah
# Processing Record 6 of Set 7 | aykhal
# Processing Record 7 of Set 7 | el tigre
# Processing Record 8 of Set 7 | paris
# Processing Record 9 of Set 7 | kununurra
# Processing Record 10 of Set 7 | santo domingo
# Processing Record 11 of Set 7 | beringovskiy
# Processing Record 12 of Set 7 | qiongshan
# Processing Record 13 of Set 7 | road town
# Processing Record 14 of Set 7 | monrovia
# Processing Record 15 of Set 7 | nova olimpia
# Processing Record 16 of Set 7 | rota
# Processing Record 17 of Set 7 | porto novo
# Processing Record 18 of Set 7 | saint-pierre
# Processing Record 19 of Set 7 | bubaque
# Processing Record 20 of Set 7 | inhambane
# Processing Record 21 of Set 7 | namatanai
# Processing Record 22 of Set 7 | worthington
# Processing Record 23 of Set 7 | sobolevo
# Processing Record 24 of Set 7 | carnarvon
# Processing Record 25 of Set 7 | viedma
# Processing Record 26 of Set 7 | el vigia
# Processing Record 27 of Set 7 | roald
# Processing Record 28 of Set 7 | kahului
# Processing Record 29 of Set 7 | richmond
# Processing Record 30 of Set 7 | dingle
# Processing Record 31 of Set 7 | talcher
# Processing Record 32 of Set 7 | luderitz
# Processing Record 33 of Set 7 | boyabat
# Processing Record 34 of Set 7 | pundaguitan
# Processing Record 35 of Set 7 | maceio
# Processing Record 36 of Set 7 | kingaroy
# Processing Record 37 of Set 7 | port blair
# Processing Record 38 of Set 7 | rodrigues alves
# Processing Record 39 of Set 7 | tautira
# Processing Record 40 of Set 7 | zyryanka
# Processing Record 41 of Set 7 | yinchuan
# Processing Record 42 of Set 7 | zhangye
# Processing Record 43 of Set 7 | santa maria
# Processing Record 44 of Set 7 | bethal
# Processing Record 45 of Set 7 | kamenka
# Processing Record 46 of Set 7 | jalu
# Processing Record 47 of Set 7 | camacari
# Processing Record 48 of Set 7 | atbasar
# Processing Record 49 of Set 7 | bela
# Processing Record 50 of Set 7 | nikolskoye
# Processing Record 1 of Set 8 | vostok
# Processing Record 2 of Set 8 | valentin gomez farias
# Processing Record 3 of Set 8 | englewood
# Processing Record 4 of Set 8 | pontianak
# Processing Record 5 of Set 8 | nome
# Processing Record 6 of Set 8 | hervey bay
# Processing Record 7 of Set 8 | nemuro
# Processing Record 8 of Set 8 | mwanza
# Processing Record 9 of Set 8 | gorontalo
# Processing Record 10 of Set 8 | komsomolskiy
# Processing Record 11 of Set 8 | conceicao do araguaia
# Processing Record 12 of Set 8 | mweka
# Processing Record 13 of Set 8 | bengkulu
# Processing Record 14 of Set 8 | sakaiminato
# Processing Record 15 of Set 8 | dunedin
# Processing Record 16 of Set 8 | lusambo
# Processing Record 17 of Set 8 | saint anthony
# Processing Record 18 of Set 8 | praia da vitoria
# Processing Record 19 of Set 8 | jardim
# Processing Record 20 of Set 8 | estrela
# Processing Record 21 of Set 8 | marchena
# Processing Record 22 of Set 8 | erzin
# Processing Record 23 of Set 8 | wana
# Processing Record 24 of Set 8 | auki
# Processing Record 25 of Set 8 | la ciotat
# Processing Record 26 of Set 8 | omboue
# Processing Record 27 of Set 8 | asheboro
# Processing Record 28 of Set 8 | karlskrona
# Processing Record 29 of Set 8 | praia
# Processing Record 30 of Set 8 | ahipara
# Processing Record 31 of Set 8 | zhoucun
# Processing Record 32 of Set 8 | bambous
# Processing Record 33 of Set 8 | pirapo
# Processing Record 34 of Set 8 | san patricio
# Processing Record 35 of Set 8 | umm lajj
# Processing Record 36 of Set 8 | dieppe
# Processing Record 37 of Set 8 | honiara
# Processing Record 38 of Set 8 | sal rei
# Processing Record 39 of Set 8 | tsumeb
# Processing Record 40 of Set 8 | piura
# Processing Record 41 of Set 8 | salvador
# Processing Record 42 of Set 8 | lata
# Processing Record 43 of Set 8 | shelburne
# Processing Record 44 of Set 8 | duma
# Processing Record 45 of Set 8 | husavik
# Processing Record 46 of Set 8 | durban
# Processing Record 47 of Set 8 | irbil
# Processing Record 48 of Set 8 | xinyu
# Processing Record 49 of Set 8 | mount isa
# Processing Record 50 of Set 8 | cap malheureux
# Processing Record 1 of Set 9 | baracoa
# Processing Record 2 of Set 9 | kuala terengganu
# Processing Record 3 of Set 9 | acapulco
# Processing Record 4 of Set 9 | aden
# Processing Record 5 of Set 9 | camacupa
# Processing Record 6 of Set 9 | nanakuli
# Processing Record 7 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 9 | barth
# Processing Record 9 of Set 9 | nanortalik
# Processing Record 10 of Set 9 | coquimbo
# Processing Record 11 of Set 9 | grants
# Processing Record 12 of Set 9 | thibodaux
# Processing Record 13 of Set 9 | cotacachi
# Processing Record 14 of Set 9 | ayame
# Processing Record 15 of Set 9 | nacogdoches
# Processing Record 16 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 17 of Set 9 | ocos
# Processing Record 18 of Set 9 | juybar
# Processing Record 19 of Set 9 | tucuman
# Processing Record 20 of Set 9 | glens falls
# Processing Record 21 of Set 9 | olafsvik
# Processing Record 22 of Set 9 | moranbah
# Processing Record 23 of Set 9 | kalmunai
# Processing Record 24 of Set 9 | san jose de guanipa
# Processing Record 25 of Set 9 | saint-louis
# Processing Record 26 of Set 9 | kamloops
# Processing Record 27 of Set 9 | mezen
# Processing Record 28 of Set 9 | kruisfontein
# Processing Record 29 of Set 9 | meulaboh
# Processing Record 30 of Set 9 | benjamin constant
# Processing Record 31 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 9 | hami
# Processing Record 33 of Set 9 | toamasina
# Processing Record 34 of Set 9 | puquio
# Processing Record 35 of Set 9 | xai-xai
# Processing Record 36 of Set 9 | moscow
# Processing Record 37 of Set 9 | constitucion
# Processing Record 38 of Set 9 | kumta
# Processing Record 39 of Set 9 | verkhoyansk
# Processing Record 40 of Set 9 | torbeyevo
# Processing Record 41 of Set 9 | arklow
# Processing Record 42 of Set 9 | kjollefjord
# Processing Record 43 of Set 9 | urusha
# Processing Record 44 of Set 9 | kerki
# City not found. Skipping...
# Processing Record 45 of Set 9 | westport
# Processing Record 46 of Set 9 | anadyr
# Processing Record 47 of Set 9 | ternate
# Processing Record 48 of Set 9 | pafos
# Processing Record 49 of Set 9 | tabou
# Processing Record 50 of Set 9 | severo-kurilsk
# Processing Record 1 of Set 10 | grand gaube
# Processing Record 2 of Set 10 | port-cartier
# Processing Record 3 of Set 10 | east london
# Processing Record 4 of Set 10 | las vegas
# Processing Record 5 of Set 10 | laguna
# Processing Record 6 of Set 10 | nizhniy odes
# Processing Record 7 of Set 10 | itarema
# Processing Record 8 of Set 10 | tapalpa
# Processing Record 9 of Set 10 | mayor pablo lagerenza
# Processing Record 10 of Set 10 | mayumba
# Processing Record 11 of Set 10 | lashio
# Processing Record 12 of Set 10 | trinidad
# Processing Record 13 of Set 10 | fukue
# Processing Record 14 of Set 10 | khingansk
# Processing Record 15 of Set 10 | haines junction
# Processing Record 16 of Set 10 | sur
# Processing Record 17 of Set 10 | madarounfa
# Processing Record 18 of Set 10 | mount gambier
# Processing Record 19 of Set 10 | gasa
# Processing Record 20 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 10 | gamba
# Processing Record 22 of Set 10 | fare
# Processing Record 23 of Set 10 | isangel
# Processing Record 24 of Set 10 | krasnoselkup
# Processing Record 25 of Set 10 | khasan
# Processing Record 26 of Set 10 | abonnema
# Processing Record 27 of Set 10 | acajutla
# Processing Record 28 of Set 10 | port-gentil
# Processing Record 29 of Set 10 | vila franca do campo
# Processing Record 30 of Set 10 | manggar
# Processing Record 31 of Set 10 | mgandu
# Processing Record 32 of Set 10 | goteborg
# City not found. Skipping...
# Processing Record 33 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 10 | aquiraz
# Processing Record 35 of Set 10 | yurla
# Processing Record 36 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 10 | marystown
# Processing Record 38 of Set 10 | takhtamygda
# Processing Record 39 of Set 10 | tsaratanana
# Processing Record 40 of Set 10 | mosquera
# Processing Record 41 of Set 10 | tiznit
# Processing Record 42 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 10 | dubai
# Processing Record 44 of Set 10 | buraydah
# Processing Record 45 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 46 of Set 10 | malakal
# Processing Record 47 of Set 10 | carlibaba
# Processing Record 48 of Set 10 | souillac
# Processing Record 49 of Set 10 | novoagansk
# Processing Record 50 of Set 10 | faya
# Processing Record 1 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 2 of Set 11 | san policarpo
# Processing Record 3 of Set 11 | ketchikan
# Processing Record 4 of Set 11 | albury
# Processing Record 5 of Set 11 | allada
# Processing Record 6 of Set 11 | liverpool
# Processing Record 7 of Set 11 | parvatipuram
# Processing Record 8 of Set 11 | linxia
# Processing Record 9 of Set 11 | havelock
# Processing Record 10 of Set 11 | jerome
# Processing Record 11 of Set 11 | alugan
# Processing Record 12 of Set 11 | xining
# Processing Record 13 of Set 11 | tanout
# Processing Record 14 of Set 11 | hambantota
# Processing Record 15 of Set 11 | ekhabi
# Processing Record 16 of Set 11 | thanatpin
# Processing Record 17 of Set 11 | phek
# Processing Record 18 of Set 11 | mazatlan
# Processing Record 19 of Set 11 | kepala batas
# Processing Record 20 of Set 11 | harnai
# Processing Record 21 of Set 11 | dingli
# Processing Record 22 of Set 11 | tahoua
# Processing Record 23 of Set 11 | catamarca
# Processing Record 24 of Set 11 | banepa
# Processing Record 25 of Set 11 | bratsk
# Processing Record 26 of Set 11 | belyy yar
# Processing Record 27 of Set 11 | nouadhibou
# Processing Record 28 of Set 11 | sistranda
# Processing Record 29 of Set 11 | awjilah
# Processing Record 30 of Set 11 | wellington
# Processing Record 31 of Set 11 | tefe
# Processing Record 32 of Set 11 | is
# City not found. Skipping...
# Processing Record 33 of Set 11 | yulara
# Processing Record 34 of Set 11 | miami
# Processing Record 35 of Set 11 | baykit
# Processing Record 36 of Set 11 | nola
# Processing Record 37 of Set 11 | carauari
# Processing Record 38 of Set 11 | takoradi
# Processing Record 39 of Set 11 | seversk
# Processing Record 40 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 11 | kavieng
# Processing Record 42 of Set 11 | kitob
# Processing Record 43 of Set 11 | poum
# Processing Record 44 of Set 11 | maarianhamina
# Processing Record 45 of Set 11 | kutum
# Processing Record 46 of Set 11 | airai
# Processing Record 47 of Set 11 | bhimunipatnam
# Processing Record 48 of Set 11 | disna
# Processing Record 49 of Set 11 | impfondo
# Processing Record 50 of Set 11 | padang
# Processing Record 1 of Set 12 | sorland
# Processing Record 2 of Set 12 | college
# Processing Record 3 of Set 12 | broome
# Processing Record 4 of Set 12 | kedarnath
# City not found. Skipping...
# Processing Record 5 of Set 12 | catalao
# Processing Record 6 of Set 12 | bardiyah
# Processing Record 7 of Set 12 | igarka
# Processing Record 8 of Set 12 | santa
# Processing Record 9 of Set 12 | pangnirtung
# Processing Record 10 of Set 12 | daru
# Processing Record 11 of Set 12 | saint-augustin
# Processing Record 12 of Set 12 | malartic
# Processing Record 13 of Set 12 | krasnyy chikoy
# Processing Record 14 of Set 12 | severobaykalsk
# Processing Record 15 of Set 12 | skibbereen
# Processing Record 16 of Set 12 | balikpapan
# Processing Record 17 of Set 12 | leh
# Processing Record 18 of Set 12 | makat
# Processing Record 19 of Set 12 | gemena
# Processing Record 20 of Set 12 | abbeville
# Processing Record 21 of Set 12 | jodhpur
# Processing Record 22 of Set 12 | vestmannaeyjar
# Processing Record 23 of Set 12 | bose
# Processing Record 24 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 25 of Set 12 | virginia beach
# Processing Record 26 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 12 | leshukonskoye
# Processing Record 28 of Set 12 | dinghai
# Processing Record 29 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 12 | vertientes
# Processing Record 31 of Set 12 | watsa
# Processing Record 32 of Set 12 | csany
# Processing Record 33 of Set 12 | chadiza
# Processing Record 34 of Set 12 | nuuk
# Processing Record 35 of Set 12 | havoysund
# Processing Record 36 of Set 12 | lucapa
# Processing Record 37 of Set 12 | kamaishi
# Processing Record 38 of Set 12 | pauini
# Processing Record 39 of Set 12 | sao miguel
# Processing Record 40 of Set 12 | touros
# Processing Record 41 of Set 12 | presidencia roque saenz pena
# Processing Record 42 of Set 12 | tacoronte
# Processing Record 43 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 44 of Set 12 | olney
# Processing Record 45 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 46 of Set 12 | treinta y tres
# Processing Record 47 of Set 12 | fort-shevchenko
# Processing Record 48 of Set 12 | garissa
# Processing Record 49 of Set 12 | sola
# Processing Record 50 of Set 12 | tungor
# Processing Record 1 of Set 13 | aswan
# Processing Record 2 of Set 13 | salur
# Processing Record 3 of Set 13 | menzelinsk
# Processing Record 4 of Set 13 | vila
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 563

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)# YOUR CODE HERE

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Kizukuri  40.8061  140.3861     57.52        59         100        4.85
# 1      Ushuaia -54.8000  -68.3000     38.86        87          40       10.36
# 2       Sorong  -0.8833  131.2500     83.26        73          55        4.41
# 3       Pompeu -19.2244  -44.9353     71.29        62          11        2.86
# 4         Hilo  19.7297 -155.0900     80.28        88         100        3.00
# 5    Dharchula  29.8500   80.5333     71.80        77         100        3.83
# 6  Port Alfred -33.5906   26.8910     60.19        92          62        4.00
# 7       Matara   5.9485   80.5353     81.27        77         100       15.08
# 8   Butaritari   3.0707  172.7902     82.49        72           7       14.52
# 9       Zlitan  32.4674   14.5687     71.78        62           0        9.13
#
#   Country                 Date Current Description
# 0      JP  2022-10-06 04:26:19     overcast clouds
# 1      AR  2022-10-06 04:21:57    scattered clouds
# 2      ID  2022-10-06 04:26:19       broken clouds
# 3      BR  2022-10-06 04:26:20          few clouds
# 4      US  2022-10-06 04:26:20       moderate rain
# 5      IN  2022-10-06 04:26:20     overcast clouds
# 6      ZA  2022-10-06 04:26:21       broken clouds
# 7      LK  2022-10-06 04:26:21     overcast clouds
# 8      KI  2022-10-06 04:26:22           clear sky
# 9      LY  2022-10-06 04:26:22           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = ["City", "Country", "Date", "Lat", "Lng","Current Description",
                    "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]



# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df = city_data_df[new_column_order]
# Display sample data
# YOUR CODE HERE
city_data_df
# Out:
#            City Country                 Date      Lat       Lng  \
# 0      Kizukuri      JP  2022-10-06 04:26:19  40.8061  140.3861
# 1       Ushuaia      AR  2022-10-06 04:21:57 -54.8000  -68.3000
# 2        Sorong      ID  2022-10-06 04:26:19  -0.8833  131.2500
# 3        Pompeu      BR  2022-10-06 04:26:20 -19.2244  -44.9353
# 4          Hilo      US  2022-10-06 04:26:20  19.7297 -155.0900
# ..          ...     ...                  ...      ...       ...
# 558      Tungor      RU  2022-10-06 04:40:33  53.3808  142.9564
# 559       Aswan      EG  2022-10-06 04:41:33  24.0934   32.9070
# 560       Salur      IN  2022-10-06 04:41:33  18.5333   83.2167
# 561  Menzelinsk      RU  2022-10-06 04:41:34  55.7271   53.1026
# 562        Vila      PT  2022-10-06 04:41:34  42.0304   -8.1588
#
#     Current Description  Max Temp  Humidity  Cloudiness  Wind Speed
# 0       overcast clouds     57.52        59         100        4.85
# 1      scattered clouds     38.86        87          40       10.36
# 2         broken clouds     83.26        73          55        4.41
# 3            few clouds     71.29        62          11        2.86
# 4         moderate rain     80.28        88         100        3.00
# ..                  ...       ...       ...         ...         ...
# 558          light rain     38.39        59          91       17.98
# 559           clear sky     83.50        32           0        5.75
# 560     overcast clouds     80.01        85         100        3.53
# 561          light rain     47.41        90         100       11.07
# 562     overcast clouds     54.48        90          98        5.21
#
# [563 rows x 10 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Date                    object
# Lat                    float64
# Lng                    float64
# Current Description     object
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
